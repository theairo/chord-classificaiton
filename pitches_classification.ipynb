# %%
import numpy as np
import librosa
from pathlib import Path
import random

directory = Path("Pitches")

max_frames = 40  # fix length for all samples

features = []
labels = []

def augment_audio(y, sr):
    """Apply random audio augmentation to waveform y."""
    
    augmentations = ['gaussian', 'background', 'time', None]
    choice = random.choice(augmentations)
    
    if choice == 'gaussian':
        noise_factor = random.uniform(0.002, 0.02)
        noise = np.random.randn(len(y))
        y = y + noise_factor * noise
        y = np.clip(y, -1.0, 1.0)
    
    elif choice == 'background':
        snr_db = random.uniform(1, 10)  # Signal-to-noise ratio in dB
        noise = np.random.randn(len(y))
        rms_signal = np.sqrt(np.mean(y**2))
        rms_noise = np.sqrt(np.mean(noise**2))
        desired_rms_noise = rms_signal / (10**(snr_db/20))
        noise = noise * (desired_rms_noise / (rms_noise + 1e-6))
        y = np.clip(y + noise, -1.0, 1.0)
    
    elif choice == 'time':
        rate = random.uniform(0.93, 1.06)
        y = librosa.effects.time_stretch(y=y, rate=rate)
    
    return y

for file in directory.rglob("*"):
    if file.is_file():
        filename = file.stem
        chord_name = filename.split('_')[0]  # adjust as needed

        for i in range(10):
            y, sr = librosa.load(str(file))
            y = augment_audio(y, sr)  # apply augmentation

            # Chroma CQT feature
            chroma = librosa.feature.chroma_cqt(y=y, sr=sr, bins_per_octave=36)
            chroma = chroma / (np.sum(chroma, axis=0, keepdims=True) + 1e-6)

            # Pad or truncate chroma to fixed length
            if chroma.shape[1] < max_frames:
                pad_width = max_frames - chroma.shape[1]
                chroma = np.pad(chroma, ((0, 0), (0, pad_width)), mode='constant')
            else:
                chroma = chroma[:, :max_frames]

            features.append(chroma)
            labels.append(chord_name)
    
X_mel = np.array(features)  # shape: (num_samples, 40, max_frames)

# Convert to numpy arrays
X = np.array(features)   # shape: (samples, 12, max_frames)
y = np.array(labels)

import numpy as np

X_mean = np.mean(X, axis=2)  # mean chroma per pitch class → shape (samples, 12)
X_std = np.std(X, axis=2)    # std chroma per pitch class → shape (samples, 12)

# Concatenate mean and std features
X_summary = np.concatenate([X_mean, X_std], axis=1)  # shape (samples, 24)
# Out:
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=87
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=740
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=370
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=185
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=93
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=707
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=354
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=177
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=89
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=653
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=327
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=164
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=82
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=710
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=355
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=178
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=694
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=347
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=174
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=665
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=333
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=167
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=84
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=682
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=341
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=171
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=86
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=706
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=353
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=654
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=724
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=362
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=181
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=91
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=658
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=329
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=165
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=83
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=725
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=363
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=182
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=729
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=365
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=183
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=92
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=732
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=366
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=677
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=339
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=170
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=85
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=719
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=360
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=180
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=90
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=720
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=700
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=350
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=175
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=88
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=721
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=361
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=669
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=335
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=168
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=692
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=346
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=733
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=367
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=184
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=738
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=369
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=660
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=330
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=734
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=678
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=731
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=655
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=328
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=666
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=693
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=663
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=332
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=166
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=684
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=342
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=705
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=739
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=685
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=343
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=172
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=688
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=344
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=717
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=359
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=673
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=337
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=169
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=695
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=348
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=713
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=357
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=179
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=718
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=656
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=672
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=336
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=723
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=703
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=352
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=176
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=704
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=702
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=351
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=736
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=368
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=715
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=358
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=730
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=670
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=659
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=652
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=326
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=163
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=726
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=716
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=662
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=331
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=699
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=683
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=676
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=338
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=671
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=697
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=349
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=667
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=334
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=698
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=728
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=364
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=651
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=741
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=371
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=186
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=701
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=714
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=711
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=356
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=727
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=661
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=737
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=679
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=340
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=709
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=691
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=681
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=680
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=668
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=674
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=664
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=686
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=696
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=689
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=687
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=708
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=712
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=722
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=735
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=657
#   warnings.warn(
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=675
#   warnings.warn(

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score

X = np.array(features)   # shape: (samples, 12, max_frames)
y = np.array(labels)


le = LabelEncoder()
y_encoded = le.fit_transform(y)

X_train, X_valid, y_train, y_valid = train_test_split(
    X_summary, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

model = SVC(kernel="rbf")

cv = cross_val_score(model, X_summary, y, cv=5)

print(cv.mean())

model.fit(X_train, y_train)

y_pred = model.predict(X_valid)

y_pred_labels = le.inverse_transform(y_pred)
y_valid_labels = le.inverse_transform(y_valid)

acc = accuracy_score(y_pred, y_valid)

print(acc)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_valid_labels, y_pred_labels)
ConfusionMatrixDisplay(cm).plot()

y_pred.shape


import pandas as pd

df = pd.DataFrame({"Label": y_pred_labels, "Class": y_pred})

df[['Label', 'Class']].drop_duplicates().sort_values('Label')
# Out:
# 0.7444444444444445
# 0.7222222222222222
#    Label  Class
# 9      A      0
# 5     A#      1
# 0      B      2
# 1      C      3
# 15    C#      4
# 6      D      5
# 28    D#      6
# 2      E      7
# 4      F      8
# 7     F#      9
# 10     G     10
# 29    G#     11

# %%
import time
import numpy as np

def measure_latency(model, X_sample, n_runs=1000, warmup=10):
    # Warmup runs (JIT compilers / caches)
    for _ in range(warmup):
        _ = model.predict(X_sample)
    
    start = time.perf_counter()
    for _ in range(n_runs):
        _ = model.predict(X_sample)
    end = time.perf_counter()
    
    avg_ms = (end - start) / n_runs * 1000
    return avg_ms

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB

# Define models
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Decision Tree": DecisionTreeClassifier(max_depth=5),
    "Naive Bayes": GaussianNB()
}

# Train & measure
for name, model in models.items():
    model.fit(X_train, y_train)
    latency = measure_latency(model, X_valid[:1])  # single sample
    print(f"{name}: {latency:.4f} ms per prediction")
    y_pred = model.predict(X_valid)
    accuracy = accuracy_score(y_valid, y_pred)
    print(accuracy)
# Out:
# Logistic Regression: 0.0747 ms per prediction
# 0.9675925925925926
# Decision Tree: 0.0855 ms per prediction
# 0.4675925925925926
# Naive Bayes: 0.3131 ms per prediction
# 0.9629629629629629

# %% [markdown]
# # CNN

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score

# Assuming X and y are loaded from your preprocessing

# Add channel dimension
X_cnn = X[..., np.newaxis]  # (samples, 12, max_frames, 1)

# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Train-validation split
X_train, X_valid, y_train, y_valid = train_test_split(
    X_cnn, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

num_classes = len(le.classes_)
y_train_cat = to_categorical(y_train, num_classes)
y_valid_cat = to_categorical(y_valid, num_classes)

# Define model
model = Sequential([
    Conv2D(32, (3, 3), padding='same', input_shape=(12, X.shape[2], 1)),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    Conv2D(64, (3, 3), padding='same'),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    Flatten(),

    Dense(256),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    Dropout(0.3),

    Dense(128),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    Dropout(0.2),

    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=50,
    restore_best_weights=True
)

history = model.fit(
    X_train, y_train_cat,
    validation_data=(X_valid, y_valid_cat),
    epochs=100,
    batch_size=32,
    verbose=2,
    callbacks=[early_stop]
)

y_pred_prob = model.predict(X_valid)
y_pred = np.argmax(y_pred_prob, axis=1)

acc = accuracy_score(y_valid, y_pred)
print(f"Validation Accuracy: {acc:.4f}")

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_valid, y_pred)
ConfusionMatrixDisplay(cm).plot()
# Out:
# Epoch 1/100
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 105/105 - 5s - 46ms/step - accuracy: 0.7896 - loss: 0.7713 - val_accuracy: 0.1476 - val_loss: 2.7666
# Epoch 2/100
# 105/105 - 1s - 13ms/step - accuracy: 0.9378 - loss: 0.2396 - val_accuracy: 0.1107 - val_loss: 2.5240
# Epoch 3/100
# 105/105 - 1s - 13ms/step - accuracy: 0.9580 - loss: 0.1526 - val_accuracy: 0.2929 - val_loss: 1.8049
# Epoch 4/100
# 105/105 - 1s - 13ms/step - accuracy: 0.9682 - loss: 0.1170 - val_accuracy: 0.6762 - val_loss: 0.8156
# Epoch 5/100
# 105/105 - 1s - 13ms/step - accuracy: 0.9750 - loss: 0.0960 - val_accuracy: 0.8702 - val_loss: 0.3463
# Epoch 6/100
# 105/105 - 1s - 13ms/step - accuracy: 0.9735 - loss: 0.0854 - val_accuracy: 0.9667 - val_loss: 0.1231
# Epoch 7/100
# 105/105 - 1s - 14ms/step - accuracy: 0.9807 - loss: 0.0601 - val_accuracy: 0.9917 - val_loss: 0.0364
# Epoch 8/100
# 105/105 - 1s - 14ms/step - accuracy: 0.9845 - loss: 0.0581 - val_accuracy: 0.9929 - val_loss: 0.0264
# Epoch 9/100
# 105/105 - 1s - 14ms/step - accuracy: 0.9884 - loss: 0.0426 - val_accuracy: 0.9869 - val_loss: 0.0415
# Epoch 10/100
# 105/105 - 1s - 14ms/step - accuracy: 0.9902 - loss: 0.0355 - val_accuracy: 0.9964 - val_loss: 0.0113
# Epoch 11/100
# 105/105 - 1s - 14ms/step - accuracy: 0.9902 - loss: 0.0342 - val_accuracy: 0.9881 - val_loss: 0.0282
# Epoch 12/100
# 105/105 - 1s - 13ms/step - accuracy: 0.9905 - loss: 0.0352 - val_accuracy: 0.9964 - val_loss: 0.0163
# Epoch 13/100
# 105/105 - 1s - 13ms/step - accuracy: 0.9914 - loss: 0.0289 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 14/100
# 105/105 - 1s - 13ms/step - accuracy: 0.9932 - loss: 0.0285 - val_accuracy: 0.9845 - val_loss: 0.0440
# Epoch 15/100
# 105/105 - 2s - 16ms/step - accuracy: 0.9905 - loss: 0.0306 - val_accuracy: 1.0000 - val_loss: 0.0074
# Epoch 16/100
# 105/105 - 2s - 17ms/step - accuracy: 0.9932 - loss: 0.0231 - val_accuracy: 0.9952 - val_loss: 0.0119
# Epoch 17/100
# 105/105 - 2s - 14ms/step - accuracy: 0.9949 - loss: 0.0190 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 18/100
# 105/105 - 2s - 15ms/step - accuracy: 0.9940 - loss: 0.0213 - val_accuracy: 0.9964 - val_loss: 0.0136
# Epoch 19/100
# 105/105 - 2s - 15ms/step - accuracy: 0.9958 - loss: 0.0158 - val_accuracy: 0.9964 - val_loss: 0.0128
# Epoch 20/100
# 105/105 - 2s - 15ms/step - accuracy: 0.9943 - loss: 0.0189 - val_accuracy: 0.9905 - val_loss: 0.0293
# Epoch 21/100
# 105/105 - 2s - 15ms/step - accuracy: 0.9923 - loss: 0.0251 - val_accuracy: 0.9905 - val_loss: 0.0270
# Epoch 22/100
# 105/105 - 2s - 15ms/step - accuracy: 0.9926 - loss: 0.0197 - val_accuracy: 0.9488 - val_loss: 0.1710
# Epoch 23/100
# 105/105 - 2s - 16ms/step - accuracy: 0.9949 - loss: 0.0171 - val_accuracy: 0.9595 - val_loss: 0.1187
# Epoch 24/100
# 105/105 - 2s - 16ms/step - accuracy: 0.9940 - loss: 0.0204 - val_accuracy: 0.9524 - val_loss: 0.1628
# Epoch 25/100
# 105/105 - 2s - 16ms/step - accuracy: 0.9943 - loss: 0.0180 - val_accuracy: 0.9940 - val_loss: 0.0186
# Epoch 26/100
# 105/105 - 2s - 15ms/step - accuracy: 0.9970 - loss: 0.0109 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 27/100
# 105/105 - 2s - 15ms/step - accuracy: 0.9985 - loss: 0.0067 - val_accuracy: 0.9988 - val_loss: 0.0036
# Epoch 28/100
# 105/105 - 2s - 16ms/step - accuracy: 0.9976 - loss: 0.0107 - val_accuracy: 0.9976 - val_loss: 0.0085
# Epoch 29/100
# 105/105 - 2s - 16ms/step - accuracy: 0.9955 - loss: 0.0139 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 30/100
# 105/105 - 2s - 15ms/step - accuracy: 0.9970 - loss: 0.0116 - val_accuracy: 0.9976 - val_loss: 0.0083
# Epoch 31/100
# 105/105 - 2s - 15ms/step - accuracy: 0.9955 - loss: 0.0143 - val_accuracy: 0.9929 - val_loss: 0.0206
# Epoch 32/100
# 105/105 - 2s - 16ms/step - accuracy: 0.9955 - loss: 0.0168 - val_accuracy: 0.9976 - val_loss: 0.0086
# Epoch 33/100
# 105/105 - 2s - 17ms/step - accuracy: 0.9937 - loss: 0.0173 - val_accuracy: 0.9214 - val_loss: 0.2255
# Epoch 34/100
# 105/105 - 2s - 16ms/step - accuracy: 0.
100
# 105/105 - 2s - 14ms/step - accuracy: 0.9964 - loss: 0.0128 - val_accuracy: 0.9976 - val_loss: 0.0146
# Epoch 73/100
# 105/105 - 2s - 14ms/step - accuracy: 0.9949 - loss: 0.0130 - val_accuracy: 1.0000 - val_loss: 3.9204e-04
# Epoch 74/100
# 105/105 - 1s - 14ms/step - accuracy: 0.9982 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 75/100
# 105/105 - 2s - 14ms/step - accuracy: 0.9970 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 6.8255e-04
# Epoch 76/100
# 105/105 - 2s - 15ms/step - accuracy: 0.9985 - loss: 0.0053 - val_accuracy: 0.9988 - val_loss: 0.0020
# Epoch 77/100
# 105/105 - 1s - 14ms/step - accuracy: 0.9961 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 78/100
# 105/105 - 2s - 14ms/step - accuracy: 0.9988 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 4.7966e-04
# Epoch 79/100
# 105/105 - 2s - 15ms/step - accuracy: 0.9973 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 4.9779e-04
# Epoch 80/100
# 105/105 - 1s - 14ms/step - accuracy: 0.9979 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 2.1890e-04
# Epoch 81/100
# 105/105 - 2s - 14ms/step - accuracy: 0.9982 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 1.6541e-04
# Epoch 82/100
# 105/105 - 2s - 15ms/step - accuracy: 0.9979 - loss: 0.0084 - val_accuracy: 0.9917 - val_loss: 0.0109
# Epoch 83/100
# 105/105 - 2s - 14ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 2.2655e-04
# Epoch 84/100
# 105/105 - 1s - 14ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 3.0114e-04
# Epoch 85/100
# 105/105 - 1s - 14ms/step - accuracy: 0.9997 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 1.7211e-04
# Epoch 86/100
# 105/105 - 2s - 15ms/step - accuracy: 0.9991 - loss: 0.0044 - val_accuracy: 0.9976 - val_loss: 0.0038
# Epoch 87/100
# 105/105 - 2s - 15ms/step - accuracy: 0.9985 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 3.7573e-04
# Epoch 88/100
# 105/105 - 2s - 14ms/step - accuracy: 0.9973 - loss: 0.0091 - val_accuracy: 0.9869 - val_loss: 0.0650
# Epoch 89/100
# 105/105 - 2s - 14ms/step - accuracy: 0.9979 - loss: 0.0046 - val_accuracy: 0.9905 - val_loss: 0.0204
# Epoch 90/100
# 105/105 - 2s - 14ms/step - accuracy: 0.9955 - loss: 0.0122 - val_accuracy: 0.9738 - val_loss: 0.0860
# Epoch 91/100
# 105/105 - 1s - 14ms/step - accuracy: 0.9982 - loss: 0.0066 - val_accuracy: 0.9940 - val_loss: 0.0142
# Epoch 92/100
# 105/105 - 1s - 14ms/step - accuracy: 0.9982 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 93/100
# 105/105 - 2s - 14ms/step - accuracy: 0.9985 - loss: 0.0045 - val_accuracy: 0.9976 - val_loss: 0.0036
# Epoch 94/100
# 105/105 - 2s - 15ms/step - accuracy: 0.9991 - loss: 0.0028 - val_accuracy: 0.9988 - val_loss: 0.0025
# Epoch 95/100
# 105/105 - 1s - 14ms/step - accuracy: 0.9970 - loss: 0.0088 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 96/100
# 105/105 - 2s - 15ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 97/100
# 105/105 - 2s - 15ms/step - accuracy: 0.9991 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 98/100
# 105/105 - 1s - 14ms/step - accuracy: 0.9985 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 2.8608e-04
# Epoch 99/100
# 105/105 - 1s - 14ms/step - accuracy: 0.9970 - loss: 0.0093 - val_accuracy: 1.0000 - val_loss: 2.6104e-04
# Epoch 100/100
# 105/105 - 2s - 14ms/step - accuracy: 0.9976 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 0.0012
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Validation Accuracy: 1.0000

# %%
latency = measure_latency(model, X_valid[:1])  # single sample
print(latency)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 latency = measure_latency(model, X_valid[:1])  # single sample
#       2 print(latency)
#
# Cell In[11], line 11, in measure_latency(model, X_sample, n_runs, warmup)
#       9 start = time.perf_counter()
#      10 for _ in range(n_runs):
# ---> 11     _ = model.predict(X_sample)
#      12 end = time.perf_counter()
#      14 avg_ms = (end - start) / n_runs * 1000
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:563, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     561 outputs = None
#     562 with epoch_iterator.catch_stop_iteration():
# --> 563     for step, iterator in epoch_iterator:
#     564         callbacks.on_predict_batch_begin(step)
#     565         data = get_data(iterator)
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:740, in TFEpochIterator.__next__(self)
#     739 def __next__(self):
# --> 740     return next(self._epoch_iterator)
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\epoch_iterator.py:111, in EpochIterator._enumerate_iterator(self)
#     109 if steps_per_epoch > 0:
#     110     if self._current_iterator is None or self.steps_per_epoch is None:
# --> 111         self._current_iterator = iter(self._get_iterator())
#     112         self._steps_seen = 0
#     113     for step in range(0, steps_per_epoch, self.steps_per_execution):
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499 if context.executing_eagerly() or ops.inside_function():
#     500   with ops.colocate_with(self._variant_tensor):
# --> 501     return iterator_ops.OwnedIterator(self)
#     502 else:
#     503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:709, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     705   if (components is not None or element_spec is not None):
#     706     raise ValueError(
#     707         "When `dataset` is provided, `element_spec` and `components` must "
#     708         "not be specified.")
# --> 709   self._create_iterator(dataset)
#     711 self._get_next_call_count = 0
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:748, in OwnedIterator._create_iterator(self, dataset)
#     745   assert len(fulltype.args[0].args[0].args) == len(
#     746       self._flat_output_types)
#     747   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 748 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3478, in make_iterator(dataset, iterator, name)
#    3476 if tld.is_eager:
#    3477   try:
# -> 3478     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3479       _ctx, "MakeIterator", name, dataset, iterator)
#    3480     return _result
#    3481   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Save entire model
model.save("pitch_detection_cnn.keras")

# %% [markdown]
# # Multi Headed CNN (paralell computing)

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, LeakyReLU, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score
import tensorflow as tf

def parse_chord(label):
    # Root is the first 1-2 chars (C, C#, D, D#, etc.)
    if len(label) > 1 and label[1] == '#':
        root = label[:2]
        quality = 'minor' if 'm' in label[2:] else 'major'
    else:
        root = label[0]
        quality = 'minor' if 'm' in label[1:] else 'major'
    return root, quality

roots, qualities = zip(*[parse_chord(lbl) for lbl in y])
roots = np.array(roots)
qualities = np.array(qualities)


# X shape: (samples, 12, max_frames)
X_cnn = X[..., np.newaxis]

# Suppose y contains full chord labels like 'C_major', 'D_minor', etc.
# We'll split them into quality and root
quality = np.array(['major' if 'major' in label else 'minor' for label in y])
root    = np.array([label.split('_')[0] for label in y])

le_root = LabelEncoder()
y_root_enc = le_root.fit_transform(roots)
y_root_cat = to_categorical(y_root_enc, num_classes=len(le_root.classes_))

le_quality = LabelEncoder()
y_quality_enc = le_quality.fit_transform(qualities)
y_quality_cat = to_categorical(y_quality_enc, num_classes=2)
# Train-validation split
X_train, X_valid, yq_train, yq_valid, yr_train, yr_valid = train_test_split(
    X_cnn, y_quality_cat, y_root_cat, test_size=0.2, random_state=42, stratify=y_quality_enc
)

# Input
inputs = Input(shape=(12, X.shape[2], 1))

# Shared CNN Encoder
x = Conv2D(32, (3, 3), padding='same')(inputs)
x = BatchNormalization()(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(0.25)(x)

x = Conv2D(64, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(0.25)(x)

x = Flatten()(x)

x = Dense(256)(x)
x = BatchNormalization()(x)
x = LeakyReLU(alpha=0.1)(x)
x = Dropout(0.3)(x)

x = Dense(128)(x)
x = BatchNormalization()(x)
x = LeakyReLU(alpha=0.1)(x)
x = Dropout(0.2)(x)

# Multi-task heads
quality_out = Dense(2, activation='softmax', name='quality')(x)
root_out    = Dense(12, activation='softmax', name='root')(x)

model = Model(inputs=inputs, outputs=[quality_out, root_out])

def focal_loss(gamma=2.0, alpha=0.25):
    def loss_fn(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        cross_entropy = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
        pt = tf.reduce_sum(y_true * y_pred, axis=-1)
        loss = alpha * tf.pow(1. - pt, gamma) * cross_entropy
        return loss
    return loss_fn

# Compile
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss={'quality':focal_loss(gamma=2.0, alpha=0.25), 'root':'categorical_crossentropy'},
    loss_weights={'quality':1.0, 'root':0.5},  # prioritize quality
    metrics={'quality':'accuracy','root':'accuracy'}
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=50,
    restore_best_weights=True
)

# Train
history = model.fit(
    X_train, {'quality': yq_train, 'root': yr_train},
    validation_data=(X_valid, {'quality': yq_valid, 'root': yr_valid}),
    epochs=100,
    batch_size=32,
    verbose=2,
    callbacks=[early_stop]
)

# Evaluate
yq_pred_prob, yr_pred_prob = model.predict(X_valid)
yq_pred = np.argmax(yq_pred_prob, axis=1)
yr_pred = np.argmax(yr_pred_prob, axis=1)

q_acc = accuracy_score(np.argmax(yq_valid, axis=1), yq_pred)
r_acc = accuracy_score(np.argmax(yr_valid, axis=1), yr_pred)

print(f"Validation Quality Accuracy: {q_acc:.4f}")
print(f"Validation Root Accuracy: {r_acc:.4f}")
# Out:
# Epoch 1/100
# c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
#
# Epoch 84/100
# 44/44 - 1s - 14ms/step - loss: 0.0347 - quality_accuracy: 0.7135 - quality_loss: 0.0341 - root_accuracy: 1.0000 - root_loss: 0.0015 - val_loss: 0.0301 - val_quality_accuracy: 0.7630 - val_quality_loss: 0.0299 - val_root_accuracy: 1.0000 - val_root_loss: 1.1563e-04
# Epoch 85/100
# 44/44 - 1s - 14ms/step - loss: 0.0355 - quality_accuracy: 0.7084 - quality_loss: 0.0340 - root_accuracy: 0.9993 - root_loss: 0.0059 - val_loss: 0.0309 - val_quality_accuracy: 0.7543 - val_quality_loss: 0.0307 - val_root_accuracy: 1.0000 - val_root_loss: 1.1530e-04
# Epoch 86/100
# 44/44 - 1s - 14ms/step - loss: 0.0365 - quality_accuracy: 0.7279 - quality_loss: 0.0330 - root_accuracy: 0.9971 - root_loss: 0.0120 - val_loss: 0.0310 - val_quality_accuracy: 0.7168 - val_quality_loss: 0.0307 - val_root_accuracy: 1.0000 - val_root_loss: 2.2618e-04
# Epoch 87/100
# 44/44 - 1s - 15ms/step - loss: 0.0413 - quality_accuracy: 0.7098 - quality_loss: 0.0343 - root_accuracy: 0.9949 - root_loss: 0.0265 - val_loss: 0.0342 - val_quality_accuracy: 0.7283 - val_quality_loss: 0.0338 - val_root_accuracy: 1.0000 - val_root_loss: 5.6042e-04
# Epoch 88/100
# 44/44 - 1s - 14ms/step - loss: 0.0470 - quality_accuracy: 0.7149 - quality_loss: 0.0351 - root_accuracy: 0.9928 - root_loss: 0.0629 - val_loss: 0.0311 - val_quality_accuracy: 0.7139 - val_quality_loss: 0.0310 - val_root_accuracy: 1.0000 - val_root_loss: 1.4035e-04
# Epoch 89/100
# 44/44 - 1s - 14ms/step - loss: 0.0413 - quality_accuracy: 0.7004 - quality_loss: 0.0347 - root_accuracy: 0.9964 - root_loss: 0.0129 - val_loss: 0.0309 - val_quality_accuracy: 0.7428 - val_quality_loss: 0.0307 - val_root_accuracy: 1.0000 - val_root_loss: 2.8424e-04
# Epoch 90/100
# 44/44 - 1s - 13ms/step - loss: 0.0389 - quality_accuracy: 0.7012 - quality_loss: 0.0342 - root_accuracy: 0.9978 - root_loss: 0.0203 - val_loss: 0.0301 - val_quality_accuracy: 0.7428 - val_quality_loss: 0.0300 - val_root_accuracy: 1.0000 - val_root_loss: 1.4083e-04
# Epoch 91/100
# 44/44 - 1s - 13ms/step - loss: 0.0407 - quality_accuracy: 0.6867 - quality_loss: 0.0355 - root_accuracy: 0.9964 - root_loss: 0.0102 - val_loss: 0.0309 - val_quality_accuracy: 0.7775 - val_quality_loss: 0.0308 - val_root_accuracy: 1.0000 - val_root_loss: 2.0834e-04
# Epoch 92/100
# 44/44 - 1s - 13ms/step - loss: 0.0375 - quality_accuracy: 0.6990 - quality_loss: 0.0347 - root_accuracy: 0.9993 - root_loss: 0.0068 - val_loss: 0.0302 - val_quality_accuracy: 0.7659 - val_quality_loss: 0.0300 - val_root_accuracy: 1.0000 - val_root_loss: 2.8108e-04
# Epoch 93/100
# 44/44 - 1s - 14ms/step - loss: 0.0347 - quality_accuracy: 0.7164 - quality_loss: 0.0333 - root_accuracy: 0.9993 - root_loss: 0.0066 - val_loss: 0.0304 - val_quality_accuracy: 0.7254 - val_quality_loss: 0.0302 - val_root_accuracy: 1.0000 - val_root_loss: 2.7381e-04
# Epoch 94/100
# 44/44 - 1s - 16ms/step - loss: 0.0375 - quality_accuracy: 0.6881 - quality_loss: 0.0355 - root_accuracy: 0.9993 - root_loss: 0.0039 - val_loss: 0.0312 - val_quality_accuracy: 0.7110 - val_quality_loss: 0.0310 - val_root_accuracy: 1.0000 - val_root_loss: 1.6849e-04
# Epoch 95/100
# 44/44 - 1s - 14ms/step - loss: 0.0360 - quality_accuracy: 0.6961 - quality_loss: 0.0345 - root_accuracy: 0.9993 - root_loss: 0.0031 - val_loss: 0.0312 - val_quality_accuracy: 0.7601 - val_quality_loss: 0.0311 - val_root_accuracy: 1.0000 - val_root_loss: 1.0777e-04
# Epoch 96/100
# 44/44 - 1s - 14ms/step - loss: 0.0363 - quality_accuracy: 0.7192 - quality_loss: 0.0339 - root_accuracy: 0.9993 - root_loss: 0.0056 - val_loss: 0.0317 - val_quality_accuracy: 0.7890 - val_quality_loss: 0.0315 - val_root_accuracy: 1.0000 - val_root_loss: 1.0400e-04
# Epoch 97/100
# 44/44 - 1s - 13ms/step - loss: 0.0396 - quality_accuracy: 0.7156 - quality_loss: 0.0345 - root_accuracy: 0.9971 - root_loss: 0.0102 - val_loss: 0.0304 - val_quality_accuracy: 0.7861 - val_quality_loss: 0.0303 - val_root_accuracy: 1.0000 - val_root_loss: 1.2042e-04
# Epoch 98/100
# 44/44 - 1s - 13ms/step - loss: 0.0346 - quality_accuracy: 0.7200 - quality_loss: 0.0332 - root_accuracy: 0.9993 - root_loss: 0.0029 - val_loss: 0.0303 - val_quality_accuracy: 0.7890 - val_quality_loss: 0.0301 - val_root_accuracy: 1.0000 - val_root_loss: 9.6942e-05
# Epoch 99/100
# 44/44 - 1s - 13ms/step - loss: 0.0366 - quality_accuracy: 0.7069 - quality_loss: 0.0339 - root_accuracy: 0.9993 - root_loss: 0.0215 - val_loss: 0.0300 - val_quality_accuracy: 0.7572 - val_quality_loss: 0.0298 - val_root_accuracy: 1.0000 - val_root_loss: 8.3910e-05
# Epoch 100/100
# 44/44 - 1s - 13ms/step - loss: 0.0391 - quality_accuracy: 0.7164 - quality_loss: 0.0337 - root_accuracy: 0.9978 - root_loss: 0.0121 - val_loss: 0.0318 - val_quality_accuracy: 0.7457 - val_quality_loss: 0.0311 - val_root_accuracy: 1.0000 - val_root_loss: 0.0016
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Validation Quality Accuracy: 0.7832
# Validation Root Accuracy: 1.0000

# %%
import numpy as np
import tensorflow as tf
import cv2
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.applications import EfficientNetB0  # placeholder for PANNs CNN14

# Assuming you have:
# - X_mel: list or np.array of mel spectrograms (samples, mel_bins=40, time_frames=max_frames)
# - y: list or np.array of labels (strings or ints)

# Resize mel bins from 40 → 64 to match pretrained model input
def resize_mel(mel, target_bins=64):
    # mel shape: (mel_bins, time_frames)
    # cv2.resize expects (width, height) so order: (time_frames, target_bins)
    mel_resized = cv2.resize(mel, (mel.shape[1], target_bins))  # width=time_frames, height=target_bins
    return mel_resized

mel_resized = np.array([resize_mel(mel) for mel in X_mel])  # shape: (samples, 64, max_frames)
print("Resized mel shape:", mel_resized.shape)  # e.g. (num_samples, 64, max_frames)

# Add channel dimension for Conv2D
X_cnn = mel_resized[..., np.newaxis]  # (samples, 64, max_frames, 1)

# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)
num_classes = len(le.classes_)

# Split after resizing and channel add
X_train, X_valid, y_train, y_valid = train_test_split(
    X_cnn, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

y_train_cat = to_categorical(y_train, num_classes)
y_valid_cat = to_categorical(y_valid, num_classes)

# Model input shape must match X_cnn shape (excluding batch)
input_layer = Input(shape=(64, mel_resized.shape[2], 1))  # (64, max_frames, 1)

# Convert 1 channel to 3 channels for EfficientNet pretrained on ImageNet
x = tf.keras.layers.Conv2D(3, (3,3), padding='same')(input_layer)

backbone = EfficientNetB0(
    include_top=False,
    weights='imagenet',
    input_shape=(64, mel_resized.shape[2], 3)
)(x)

x = GlobalAveragePooling2D()(backbone)
x = Dropout(0.3)(x)
output_layer = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=input_layer, outputs=output_layer)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train_cat,
    validation_data=(X_valid, y_valid_cat),
    epochs=50,
    batch_size=32,
    verbose=2
)

# Evaluate
y_pred_prob = model.predict(X_valid)
y_pred = np.argmax(y_pred_prob, axis=1)
acc = accuracy_score(y_valid, y_pred)
print(f"Validation Accuracy: {acc:.4f}")
# Out:
# Resized mel shape: (1728, 64, 40)
# Epoch 1/50
# 44/44 - 47s - 1s/step - accuracy: 0.1281 - loss: 3.0423 - val_accuracy: 0.0405 - val_loss: 3.2233
# Epoch 2/50
# 44/44 - 9s - 205ms/step - accuracy: 0.3980 - loss: 2.0954 - val_accuracy: 0.0405 - val_loss: 3.2724
# Epoch 3/50
# 44/44 - 9s - 199ms/step - accuracy: 0.5572 - loss: 1.5064 - val_accuracy: 0.0405 - val_loss: 3.2888
# Epoch 4/50
# 44/44 - 9s - 198ms/step - accuracy: 0.6223 - loss: 1.1476 - val_accuracy: 0.0434 - val_loss: 3.2659
# Epoch 5/50
# 44/44 - 9s - 208ms/step - accuracy: 0.6621 - loss: 0.9297 - val_accuracy: 0.0636 - val_loss: 3.2914
# Epoch 6/50
# 44/44 - 9s - 208ms/step - accuracy: 0.7098 - loss: 0.7876 - val_accuracy: 0.0549 - val_loss: 3.2874
# Epoch 7/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 66
#      58 model = Model(inputs=input_layer, outputs=output_layer)
#      60 model.compile(
#      61     optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
#      62     loss='categorical_crossentropy',
#      63     metrics=['accuracy']
#      64 )
# ---> 66 history = model.fit(
#      67     X_train, y_train_cat,
#      68     validation_data=(X_valid, y_valid_cat),
#      69     epochs=50,
#      70     batch_size=32,
#      71     verbose=2
#      72 )
#      74 # Evaluate
#      75 y_pred_prob = model.predict(X_valid)
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:377, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375 for step, iterator in epoch_iterator:
#     376     callbacks.on_train_batch_begin(step)
# --> 377     logs = self.train_function(iterator)
#     378     callbacks.on_train_batch_end(step, logs)
#     379     if self.stop_training:
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:220, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     216 def function(iterator):
#     217     if isinstance(
#     218         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     219     ):
# --> 220         opt_outputs = multi_step_on_iterator(iterator)
#     221         if not opt_outputs.has_value():
#     222             raise StopIteration
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File c:\Users\TheAiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
